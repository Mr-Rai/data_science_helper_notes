# %% [markdown]
# **Statistics & Probability**
# 1. IQR, Q1, Q3
# 2. Box Plot
# 3. Outliers (lower/upper fence)
# 4. Gaussian / Normal Distribution
# 5. Z‑Score
# 6. Standard Normal Distribution
# 7. Z‑Table
# 8. One‑Tailed & Two‑Tailed Tests
# 9. Hypothesis Testing basics
# 10. p‑value
# 11. Significance level (α)
# 12. Confidence Intervals (Z & t)
# 13. Type I & Type II Errors
# 14. Permutations & Combinations
# 15. Probability basics (OR/AND, conditional)
#
# **Machine Learning Basics**
# 1. Supervised Learning
# 2. Multi‑Class Classification
# 3. Multi‑Label Classification
# 4. Overfitting
# 5. Underfitting
# 6. Generalization
# 7. Linear Regression
# 8. Least Squares (Ordinary Least Squares)
# 9. Polynomial Features
# 10. Relationship: weights, bias, alpha (λ)
# 11. Logistic Regression
# 12. Support Vector Machines (SVM)
# 13. Kernelized SVM
# 14. One‑Vs‑One (OvO) & One‑Vs‑Rest (OvR)
# 15. Model Evaluation & Selection
#
# **Regularization & Scaling**
# 1. Regularization (need for)
# 2. Normalization (need for)
# 3. Standardization (Z‑score)
# 4. Ridge Regression
# 5. Lasso Regression
# 6. L1 vs L2 Regularization
# 7. Normalization vs Regularization
#
# **Feature Engineering**
# 1. One‑Hot Encoding
# 2. Label Encoding
# 3. Why Red=1, Blue=2, Green=3 is wrong
# 4. Polynomial Features
# 5. Feature Normalization (need, meaning of x, x′, μ, σ)
#
# **Model Evaluation Metrics**
# 1. Accuracy
# 2. Precision
# 3. Recall
# 4. F1‑Score
# 5. Confusion Matrix
# 6. ROC‑AUC
# 7. Code examples for all metrics
#
# **Validation Techniques**
# 1. Cross‑Validation (K‑Fold, Stratified, LOOCV)
