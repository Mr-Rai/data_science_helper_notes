# %% [markdown]
# ### Source - https://www.w3schools.com/python/pandas/default.asp

# %%
import pandas as pd

# %% [markdown]
# ### Pandas Series

# %%
a = [1, 2, 3, 4, 5]

myser = pd.Series(a)
myser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### Adding labels to the series (index)

# %%
labels = ['a', 'b', 'c', 'd', 'e']
myser2 = pd.Series(a, index=labels)
myser2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
myser2['c']
# Out:
# np.int64(3)

# %% [markdown]
# ### Key/Value Objects as Series

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
dict_ser = pd.Series(calories)
dict_ser
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ### Dataframes

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ### Locate using index

# %%
df.loc[0]
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
df.loc[1]
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
df = pd.DataFrame(data, index=[f'row_{i}' for i in range(1,len(df)+1)])
df
# Out:
#        calories  duration
# row_1       420        50
# row_2       380        40
# row_3       390        45

# %%
df.loc['row_1']
# Out:
# calories    420
# duration     50
# Name: row_1, dtype: int64

# %% [markdown]
# ### Read Files From CSV

# %%
import pandas as pd
df = pd.read_csv("..\\data\\sample.csv")
df
# Out:
#    calories  duration   weight
# 0       420        50       85
# 1       380        40       64
# 2       390        45       76
# 3       200        30       68

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
df = pd.read_json("..\\data\\sample.json")
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110     130.0     409.0
# 1        60    117     145.0       NaN
# 2        60    103       NaN     340.0
# 3        45    109     175.0     282.0
# 4        45    117     148.0       NaN
# 5        60    102     127.0     300.0

# %% [markdown]
# ### Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  5 non-null      float64
#  3   Calories  4 non-null      float64
# dtypes: float64(2), int64(2)
# memory usage: 240.0 bytes

# %% [markdown]
# ### Data Describe

# %%
df.describe()
# Out:
#         Duration       Pulse    Maxpulse    Calories
# count   6.000000    6.000000    5.000000    4.000000
# mean   55.000000  109.666667  145.000000  332.750000
# std     7.745967    6.501282   19.091883   56.316812
# min    45.000000  102.000000  127.000000  282.000000
# 25%    48.750000  104.500000  130.000000  295.500000
# 50%    60.000000  109.500000  145.000000  320.000000
# 75%    60.000000  115.250000  148.000000  357.250000
# max    60.000000  117.000000  175.000000  409.000000

# %%
df.describe().loc['25%']['Pulse'], df.describe().loc['75%']['Pulse']
# Out:
# (np.float64(104.5), np.float64(115.25))

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse    float64
# Calories    float64
# dtype: object

# %% [markdown]
# ### Data Cleaning

# %%
df = pd.read_csv("..\\data\\data.csv")
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df['Date'].isnull()
df.loc[df['Date'].isnull()]
df.loc[df['Calories'].isnull()]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 18        45  '2020/12/18'     90       112       NaN
# 28        60  '2020/12/28'    103       132       NaN

# %%
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  29 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     29 non-null     int64
#  3   Maxpulse  29 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df = pd.read_csv("..\\data\\data.csv")
df.dropna(subset=['Calories'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     30 non-null     int64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df = pd.read_csv("..\\data\\data.csv")
df.fillna(0, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df = pd.read_csv("..\\data\\data.csv")
df.fillna({'Calories': df['Calories'].mean()}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df = pd.read_csv("..\\data\\data.csv")
[df.fillna({col: df[col].mean()}, inplace=True) for col in df.columns if col not in ['Date']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# ### Fix Formats

# %%
df = pd.read_csv("..\\data\\data.csv")
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      30 non-null     datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %% [markdown]
# ### Fixing wrong data

# %%
df[df['Calories'] >= 400].sort_values(by="Calories")
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 4        45 2020-12-05    117       148     406.0
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117       145     479.0

# %%
df.loc[1, "Maxpulse"] = 20000
df.head()
# Out:
#    Duration       Date  Pulse  Maxpulse  Calories
# 0        60 2020-12-01    110       130     409.1
# 1        60 2020-12-02    117     20000     479.0
# 2        60 2020-12-03    103       135     340.0
# 3        45 2020-12-04    109       175     282.4
# 4        45 2020-12-05    117       148     406.0

# %%
for x in df.index:
    if df.loc[x, 'Duration'] > 120:
        df.loc[x, 'Duration'] == 120

# %% [markdown]
# Note:
#
# - .loc[] is primarily label based, but may also be used with a boolean array.
# - .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
df.iloc[1]
# Out:
# Duration                     60
# Date        2020-12-02 00:00:00
# Pulse                       117
# Maxpulse                  20000
# Calories                  479.0
# Name: 1, dtype: object

# %%
df = pd.read_csv("..\\data\\data.csv")
print(df.info())
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.drop(x, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# ### Removing duplicates

# %%
df = pd.read_csv("..\\data\\data.csv")
df[df['Calories'].duplicated()]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 12        60  '2020/12/12'    100       120     250.7
# 17        60  '2020/12/17'    100       120     300.0
# 23        60  '2020/12/23'    130       101     300.0
# 28        60  '2020/12/28'    103       132       NaN
# 31        60  '2020/12/31'     92       115     243.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     31 non-null     int64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Correlation: Find relation among different columns
#
# The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
# - The number varies from -1 to 1.
# - 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
# - 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
# - -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
# - 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %%
df = pd.read_csv("..\\data\\sample.csv")
df.corr()
# Out:
#           calories  duration    weight
# calories  1.000000  0.943712  0.518826
# duration  0.943712  1.000000  0.772348
#  weight   0.518826  0.772348  1.000000

# %% [markdown]
# ## Plotting with pandas

# %%
# import matplotlib.pyplot as plt

df = pd.read_csv("..\\data\\data.csv")

df.plot()
# plt.show()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.plot(kind="scatter", x="Calories", y="Pulse")
# Out:
# <Axes: xlabel='Calories', ylabel='Pulse'>

# %%
df['Duration'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
