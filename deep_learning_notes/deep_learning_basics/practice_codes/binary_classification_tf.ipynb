# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
X, y = make_classification(n_samples=500, n_features=2, n_informative=2,
                           n_redundant=0, n_clusters_per_class=1, random_state=42)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss="binary_crossentropy", metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_split=0.2)
# Out:
# c:\Users\shurai\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5031 - loss: 0.5969 - val_accuracy: 0.4625 - val_loss: 0.6078
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4938 - loss: 0.5790 - val_accuracy: 0.4625 - val_loss: 0.5879
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5406 - loss: 0.5624 - val_accuracy: 0.5875 - val_loss: 0.5709
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7125 - loss: 0.5471 - val_accuracy: 0.7500 - val_loss: 0.5549
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8406 - loss: 0.5326 - val_accuracy: 0.8125 - val_loss: 0.5391
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8531 - loss: 0.5186 - val_accuracy: 0.8500 - val_loss: 0.5244
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8594 - loss: 0.5051 - val_accuracy: 0.8625 - val_loss: 0.5099
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8625 - loss: 0.4921 - val_accuracy: 0.8625 - val_loss: 0.4964
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8625 - loss: 0.4792 - val_accuracy: 0.8625 - val_loss: 0.4831
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8625 - loss: 0.4667 - val_accuracy: 0.8625 - val_loss: 0.4693
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8687 - loss: 0.4544 - val_accuracy: 0.8625 - val_loss: 0.4555
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8719 - loss: 0.4420 - val_accuracy: 0.8875 - val_loss: 0.4418
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8719 - loss: 0.4296 - val_accuracy: 0.9000 - val_loss: 0.4285
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8687 - loss: 0.4175 - val_accuracy: 0.9125 - val_loss: 0.4153
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8813 - loss: 0.4062 - val_accuracy: 0.9250 - val_loss: 0.4019
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8781 - loss: 0.3947 - val_accuracy: 0.9250 - val_loss: 0.3894
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8813 - loss: 0.3838 - val_accuracy: 0.9250 - val_loss: 0.3770
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8813 - loss: 0.3732 - val_accuracy: 0.9250 - val_loss: 0.3647
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8750 - loss: 0.3629 - val_accuracy: 0.9250 - val_loss: 0.3527
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8750 - loss: 0.3528 - val_accuracy: 0.9000 - val_loss: 0.3421
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8750 - loss: 0.3439 - val_accuracy: 0.9000 - val_loss: 0.3320
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8687 - loss: 0.3356 - val_accuracy: 0.9000 - val_loss: 0.3223
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8687 - loss: 0.3278 - val_accuracy: 0.9000 - val_loss: 0.3140
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8687 - loss: 0.3209 - val_accuracy: 0.9000 - val_loss: 0.3065
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8719 - loss: 0.3147 - val_accuracy: 0.9000 - val_loss: 0.3000
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8719 - loss: 0.3091 - val_accuracy: 0.9000 - val_loss: 0.2933
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8687 - loss: 0.3041 - val_accuracy: 0.9125 - val_loss: 0.2866
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8719 - loss: 0.2993 - val_accuracy: 0.9000 - val_loss: 0.2817
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8687 - loss: 0.2949 - val_accuracy: 0.9000 - val_loss: 0.2779
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8719 - loss: 0.2910 - val_accuracy: 0.9000 - val_loss: 0.2725

# %%
plt.figure(figsize=(8, 4))
plt.subplot(1,2,1)
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=y, cmap='bwr', edgecolors='k', alpha=0.7)
plt.title("2D Binary classification Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label="Train Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")
plt.title("Model Accuracy Vs Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
